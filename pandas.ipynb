# %%
import pandas as pd

#this is a formatted string (f-string).  It outputs exactly as you format it.  Usually has a variable inside.
print(f"pandas version: {pd.__version__}")
# Out:
# pandas version: 2.0.3

# %%
#Pandas has two main dtypes, Series & DataFrames
#pandas.Series is a 1-dimensional column of data
#pandas.DataFrame is a 2-dimensional table of data

#Create a series of car types
cars = pd.Series(["BMW", "Toyota", "Ford"])
cars
# Out:
# 0       BMW
# 1    Toyota
# 2      Ford
# dtype: object

# %%
#Creating a DataFrame
car_data = pd.DataFrame({
    "Car Type": ["BMW", "Toyota", "Ford"],
    "Colour": ["Red", "Green", "Blue"],
    "Price": ["Outrageous", "Also High", "Reasonable"],
})

car_data
# Out:
#   Car Type Colour       Price
# 0      BMW    Red  Outrageous
# 1   Toyota  Green   Also High
# 2     Ford   Blue  Reasonable

# %%
patient_data = pd.read_csv('heart-disease.csv')

patient_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
patient_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
patient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
print(patient_data['chol'].mean(numeric_only=True))

patient_data['chol'].sum(numeric_only=True)
# Out:
# 246.26402640264027
# 74618

# %%
columns = patient_data.columns

columns[0]
# Out:
# 'age'

# %%
patient_data.head(n=10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
patient_data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
patient_df = pd.DataFrame(patient_data)

#iloc stands for integer (index) location, wherewas loc just stand for location

#Get the entire column data
patient_df.loc[:,'sex']

#Get all rows up to a certain index
patient_df.loc[:3]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1

# %%
#Select patient based on a certain age threshold (condition)
patient_data[patient_data['age'] > 50] 

#Select records where gender is male
patient_data[patient_data['sex'] == 1]

#Visualize the data changes
patient_data['chol'].plot()
# Out:
# <Axes: >

# %%
#Slice rows & columns in the DataFrame

#rows
patient_df.loc[:]

#single row 
patient_df.loc[3:3]

#single column
#patient_df.loc['label']

#n-number of columns & rows
patient_df.iloc[3:5, 0:2]

#'-1' should grab the end of a column or row
#':' indicates you want to grab all of a column or row
#dropna() to drop rows with missing fields
#fillna() to fill in missing values with 0


#add a column
jump_height = [3, 3, 4, 5, 6, 7, 2, 9, 2, 3, 5, 4, 5]

new_patient_data = patient_data[:13]

new_patient_dataframe = pd.DataFrame(new_patient_data)

new_patient_dataframe['Jump Height'] = jump_height
